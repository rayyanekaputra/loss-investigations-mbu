# %%
import pandas as pd

# Read the excel file
df_beli = pd.read_excel("./Pembelian 2024 (19.05.25) Bu Dian.xlsx")

# Print the DataFrame
df_beli.head(2)
# Out:
#    Unnamed: 0            CV Makassar Boga Utama Unnamed: 2 Unnamed: 3  \
# 0         NaN      Rincian Pembelian per Barang        NaN        NaN
# 1         NaN  Dari 01 Jan 2024 s/d 31 Des 2024        NaN        NaN
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 16  Unnamed: 17  Unnamed: 18
# 0         NaN          NaN          NaN
# 1         NaN          NaN          NaN

# %%
df_beli.rename(columns=df_beli.iloc[3], inplace = True)
#Bersihkan itu kolom judul NaM
df_beli = df_beli.loc[:, ~df_beli.columns.isna()]
#Drop ki itu data2 header di excel
df_beli.drop(range(0,4), axis=0, inplace = True) 
df_beli.head(4)
# Out:
#             Nomor #              Tanggal Kode #                 Nama Barang  \
# 4  PI.2024.02.00303  2024-02-28 00:00:00  97530  137 Almond  Avocado 180 ml
# 5  PI.2024.10.00190  2024-10-16 00:00:00  97530  137 Almond  Avocado 180 ml
# 6  PI.2024.02.00303  2024-02-28 00:00:00  97528       137 Almond Avocado 1L
# 7  PI.2024.10.00190  2024-10-16 00:00:00  97528       137 Almond Avocado 1L
#
#   Kts (Unit#1) Kuantitas Satuan @Harga    Diskon Diskon %  \
# 4           36        36    Pcs  20000     72000       10
# 5           36        36    Pcs  20000     72000       10
# 6           24        24    Pcs  88358  212059.2       10
# 7           24        24    Pcs  88358  212059.2       10
#
#   Diskon Faktur Pembelian Diskon % Faktur Pembelian  \
# 4                       0                       NaN
# 5                       0                       NaN
# 6                       0                       NaN
# 7                       0                       NaN
#
# ...

# %%
df_beli['Nama Barang'].value_counts()
# Out:
# Nama Barang
# Cimory Plain Fresh Milk 950 Ml @ 12Pcs    110
# Selada keriting 250Gr / Curah (Whole)     100
# Frz China Broccoli Florets 10x1 Kg         91
# Gryvan Tomat Cherry 250gr/pck              86
# Gryvan Corriander 100gr                    69
#                                          ...
# Whole Chips Seaweed Cassava 40G             1
# Wonhae Potato Snack Spicy Korean 60 gr      1
# WRIGHT HICKORY SMOKE                        1
# Whole Chips Balado Cassava 40G              1
# AAH BISTO ORIGINAL GRAVY POWDE              1
# Name: count, Length: 1928, dtype: int64

# %%
df_beli['Satuan'].value_counts()
# Out:
# Satuan
# Pck    4122
# Pcs    2179
# Kg     2112
# Btl     623
# Ctn     220
# Can     150
# Box     101
# Pai      73
# Jar      46
# Cup      37
# Gal      10
# Tin       8
# Bow       7
# Name: count, dtype: int64

# %%
df_beli.to_excel("PembelianBuDian2024.xlsx", index=False)
